# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoSousaJesus/semana_machine_learning/blob/main/ml_pln_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algebra Linear - Revisão 1
#
# 1.   A equação linear tem **x¹** (x elevado a 1)
# 2.

# %%
def verifica_equacao(base, expoente):
  msg = ""
  if expoente == 1:
    msg = "equação linear"
  else:
    msg = "equação não linear"
    return f" resposta da potência: {pow(base,expoente)} - {msg}"

# %%
# 3 é coeficiente da variável x
# 5 (sem letra e variável) é o termo independente
# Se o termo independente for igual a 0 = Equação Linear Homogênea
# Quando não tem coeficiente é igual a 1

# %%
# chamar a função (paradigma estruturado)
# overflow - estouro de pilha de memória
verifica_equacao(5,1)

# %% [markdown]
# # POO - Paradigma Orientado a Objetos
#
# - Classe
# - Objeto
# - Método
# - Construtor
#
# **Biblioteca abc** (Abstract Basics Classes)
#
# - Classes Abstratas
# - Métodos Abstratos
# - Polimorfismo

# %%
class EquacaoLinear:
  # atributo - base e expoente
  # atributos do objeto
  def __init__(self, base, expoente):
    self.base = base
    self.expoente = expoente

  def verifica_equacao(self):
  # variáveis - msg
    msg =""
    if self.expoente == 1:
      msg = "equação linear"
    else:
      msg = "equação não linear"
    return f" resposta da potência: {pow(self.base,self.expoente)} - {msg}"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = EquacaoLinear(6,1)

# %%
a.verifica_equacao()
# Out:
# ' resposta da potência: 6 - equação linear'

# %%
verifica_equacao = lambda x : pow(x,1)

# %%
print(verifica_equacao(2))
# Out:
# 2

# %%
# prompt: crie uma lambda desse função:
# def __init__(self, base, expoente):
#     self.base = base
#     self.expoente = expoente
#   def verifica_equacao(self):
#   # variáveis - msg
#     msg =""
#     if self.expoente == 1:
#       msg = "equação linear"
#     else:
#       msg = "equação não linear"
#     return f" resposta da potência: {pow(self.base,self.expoente)} - {msg}"

verifica_equacao_lambda = lambda base, expoente: (
    "equação linear" if expoente == 1 else "equação não linear"
)

# Exemplo de uso:
base = 5
expoente = 2
resultado = verifica_equacao_lambda(base, expoente)
print(resultado)
# Out:
# equação não linear

# %%
verifica_equacao = lambda x, y : pow(x,y)
verifica_equacao(2,3)
# Out:
# 8

# %%
# prompt: Gere uma função que calcule a raiz quadrada de x
# imortando a bibliotecha
import math
# criando a função com um parâmetro
def raiz_quadrada(x):
    return math.sqrt(x)

# %%
print(f"a raiz quadrada de x é: {raiz_quadrada(256)}")
# Out:
# a raiz quadrada de x é: 16.0

# %% [markdown]
# Exercício 01: Considere a função criada anteriormente da raiz quadrada e crie duas versões multiparadigmas: uma solução com orientação a objetos e uma classe que terá o nome de Matemática, e outra solução usando lambda e ai você define o nome.

# %%
# prompt: Considere a função criada anteriormente da raiz quadrada e crie duas versões multiparadigma: uma solução com orientação a objetos e uma classe que terá o nome de Matemática, e outra solução usando lambda e ai você define o nome.

import math

class Matematica:
  def raiz_quadrada(self, x):
    return math.sqrt(x)

# Solução com Orientação a Objetos
matematica = Matematica()
resultado_oo = matematica.raiz_quadrada(25)
print(f"Resultado: {resultado_oo}")
# Out:
# Resultado: 5.0

# %%
# Solução com Lambda
raiz_quadrada_lambda = lambda x: math.sqrt(x)
resultado_lambda = raiz_quadrada_lambda(25)
print(f"Resultado: {resultado_lambda}")
# Out:
# Resultado: 5.0

# %%
# prompt: Considere a função criada anteriormente da raiz quadrada e crie duas versões multiparadigma: uma solução com orientação a objetos e uma classe que terá o nome de Matemática, e outra solução usando lambda e ai você define o nome.

import math

class Matematica:
  def __init__(self, x):
    self.x = x

  def raiz_quadrada(self):
    return math.sqrt(self.x) # math - biblioteca sqtr
  def calcular_fatorial(self):
    return math.factorial(self.x)
  def angulo(self):
    return math.radians(self.x)

# Solução com Orientação a Objetos
matematica = Matematica(5)
resultado_oo = matematica.raiz_quadrada()
print(f"Resultado: {resultado_oo}")

print(f"O fatorial de x é: {matematica.calcular_fatorial()}")
# Out:
# Resultado: 2.23606797749979
# O fatorial de x é: 120

# %%
print(f"O fatorial de x é: {matematica.calcular_fatorial()}")
# Out:
# O fatorial de x é: 120
